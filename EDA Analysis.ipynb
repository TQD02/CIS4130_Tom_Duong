# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
filepath = "gs://tom-duong-project-bucket/landing"

filelist = ['20220906.csv',
            '20220907.csv',
            '20220908.csv',
            '20220909.csv',
            '20220910.csv',
           ]

columns = ["date", "match_ID", "p1_tag", "p1_trophies", "p1_crowns_obtained", 
           "p1_unit1", "p1_unit2", "p1_unit3", "p1_unit4", "p1_unit5", 
           "p1_unit6", "p1_unit7", "p1_unit8", "p2_tag", "p2_trophies", 
           "p2_crowns_obtained", "p2_unit1", "p2_unit2", "p2_unit3", 
           "p2_unit4", "p2_unit5", "p2_unit6", "p2_unit7", "p2_unit8"]

# %%
def perform_EDA(df: pd.DataFrame, filename : str):
    
    print(f"{filename} Number of records:")
    print(df.count())
    print(f"{filename} Number of variables:")
    print(df.shape[1])
    print(f"{filename} Number of duplicate records: { len(df)-len(df.drop_duplicates())}" )
    print(f"{filename} Info")
    print(df.info())
    print(f"{filename} Describe")
    print(df.describe())
    print(f"{filename} Columns with null values")
    print(df.columns[df.isnull().any()].tolist())
    rows_with_null_values = df.isnull().any(axis=1).sum()
    print(f"{filename} Number of Rows with null values: {rows_with_null_values}" )
    integer_column_list = df.select_dtypes(include='int64').columns
    print(f"{filename} Integer data type columns: {integer_column_list}")
    float_column_list = df.select_dtypes(include='float64').columns
    print(f"{filename} Float data type columns: {float_column_list}")
    unique_counts_p1 = df.loc[:, 'p1_unit1':'p1_unit8'].nunique()
    unique_counts_p2 = df.loc[:, 'p2_unit1':'p2_unit8'].nunique()
    print(f"{filename} Unique items in p1_unit1 to p1_unit8:")
    print(unique_counts_p1)
    print(f"{filename} Unique items in p2_unit1 to p2_unit8:")
    print(unique_counts_p2)
    unique_crowns_p1 = df['p1_crowns_obtained'].nunique()
    print(f"{filename} Unique items in p1_crowns_obtained: {unique_crowns_p1}")
    unique_crowns_p2 = df['p2_crowns_obtained'].nunique()
    print(f"{filename} Unique items in p2_crowns_obtained: {unique_crowns_p2}")
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    sns.histplot(unique_counts_p1, bins=len(unique_counts_p1), kde=False)
    plt.title('Histogram of Unique Items in p1_units')
    plt.xlabel('Number of Unique Items')
    plt.ylabel('Frequency')

    plt.subplot(1, 2, 2)
    sns.histplot(unique_counts_p2, bins=len(unique_counts_p2), kde=False)
    plt.title('Histogram of Unique Items in p2_units')
    plt.xlabel('Number of Unique Items')
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()
    
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    sns.histplot(df['p1_crowns_obtained'], bins=unique_crowns_p1, kde=False)
    plt.title('Histogram of Unique Crowns Obtained by Player 1')
    plt.xlabel('Crowns Obtained')
    plt.ylabel('Frequency')

    plt.subplot(1, 2, 2)
    sns.histplot(df['p2_crowns_obtained'], bins=unique_crowns_p2, kde=False)
    plt.title('Histogram of Unique Crowns Obtained by Player 2')
    plt.xlabel('Crowns Obtained')
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
for filename in filelist:
    print(f"Working on file {filename}")
    data_df = pd.read_csv(f"{filepath}/{filename}", sep = ",",header = None)
    data_df.columns = columns
    perform_EDA(data_df,filepath)
# Out:
# Working on file 20220906.csv
# gs://tom-duong-project-bucket/landing Number of records:
# date                  29
# match_ID              29
# p1_tag                29
# p1_trophies           29
# p1_crowns_obtained    29
# p1_unit1              29
# p1_unit2              29
# p1_unit3              29
# p1_unit4              29
# p1_unit5              29
# p1_unit6              29
# p1_unit7              29
# p1_unit8              29
# p2_tag                29
# p2_trophies           29
# p2_crowns_obtained    29
# p2_unit1              29
# p2_unit2              29
# p2_unit3              29
# p2_unit4              29
# p2_unit5              29
# p2_unit6              29
# p2_unit7              29
# p2_unit8              29
# dtype: int64
# gs://tom-duong-project-bucket/landing Number of variables:
# 24
# gs://tom-duong-project-bucket/landing Number of duplicate records: 0
# gs://tom-duong-project-bucket/landing Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                29 non-null     object
#  1   match_ID            29 non-null     int64
#  2   p1_tag              29 non-null     object
#  3   p1_trophies         29 non-null     int64
#  4   p1_crowns_obtained  29 non-null     int64
#  5   p1_unit1            29 non-null     int64
#  6   p1_unit2            29 non-null     int64
#  7   p1_unit3            29 non-null     int64
#  8   p1_unit4            29 non-null     int64
#  9   p1_unit5            29 non-null     int64
#  10  p1_unit6            29 non-null     int64
#  11  p1_unit7            29 non-null     int64
#  12  p1_unit8            29 non-null     int64
#  13  p2_tag              29 non-null     object
#  14  p2_trophies         29 non-null     int64
#  15  p2_crowns_obtained  29 non-null     int64
#  16  p2_unit1            29 non-null     int64
#  17  p2_unit2            29 non-null     int64
#  18  p2_unit3            29 non-null     int64
#  19  p2_unit4            29 non-null     int64
#  20  p2_unit5            29 non-null     int64
#  21  p2_unit6            29 non-null     int64
#  22  p2_unit7            29 non-null     int64
#  23  p2_unit8            29 non-null     int64
# dtypes: int64(21), object(3)
# memory usage: 5.6+ KB
# None
# gs://tom-duong-project-bucket/landing Describe
#            match_ID  p1_trophies  p1_crowns_obtained      p1_unit1  \
# count  2.900000e+01    29.000000           29.000000  2.900000e+01
# mean   7.200001e+07  5779.655172            1.137931  2.600001e+07
# std    1.535652e+01   689.179444            1.125171  7.355170e+00
# min    7.200001e+07  5000.000000            0.000000  2.600000e+07
# 25%    7.200001e+07  5001.000000            0.000000  2.600001e+07
# 50%    7.200001e+07  6070.000000            1.000000  2.600001e+07
# 75%    7.200001e+07  6571.000000            2.000000  2.600002e+07
# max    7.200007e+07  6623.000000            3.000000  2.600004e+07
#
#            p1_unit2      p1_unit3      p1_unit4      p1_unit5      p1_unit6  \
# count  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01
# mean   2.600003e+07  2.600004e+07  2.606901e+07  2.617246e+07  2.679315e+07
# std    1.643947e+01  1.523389e+01  2.578697e+05  3.844072e+05  9.403046e+05
# min    2.600001e+07  2.600001e+07  2.600001e+07  2.600003e+07  2.600004e+07
# 25%    2.600001e+07  2.600002e+07  2.600004e+07  2.600005e+07  2.600008e+07
# 50%    2.600002e+07  2.600004e+07  2.600005e+07  2.600006e+07  2.600008e+07
# 75%    2.600004e+07  2.600005e+07  2.600006e+07  2.600007e+07  2.800000e+07
# max    2.600005e+07  2.600006e+07  2.700001e+07  2.700001e+07  2.800001e+07
#
#            p1_unit7  ...  p2_trophies  p2_crowns_obtained      p2_unit1  \
# count  2.900000e+01  ...    29.000000           29.000000  2.900000e+01
# mean   2.786208e+07  ...  5746.793103            1.137931  2.600001e+07
# std    5.157489e+05  ...   631.458141            1.156477  9.520266e+00
# min    2.600004e+07  ...  5002.000000            0.000000  2.600000e+07
# 25%    2.800000e+07  ...  5034.000000            0.000000  2.600001e+07
# 50%    2.800000e+07  ...  5920.000000            1.000000  2.600001e+07
# 75%    2.800001e+07  ...  6196.000000            2.000000  2.600002e+07
# max    2.800001e+07  ...  6632.000000            3.000000  2.600005e+07
#
#            p2_unit2      p2_unit3      p2_unit4      p2_unit5      p2_unit6  \
# count  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01
# mean   2.600002e+07  2.600003e+07  2.600004e+07  2.620694e+07  2.710347e+07
# std    1.132665e+01  1.275672e+01  1.574684e+01  4.912857e+05  8.169758e+05
# min    2.600001e+07  2.600002e+07  2.600002e+07  2.600002e+07  2.600004e+07
# 25%    2.600002e+07  2.600002e+07  2.600003e+07  2.600005e+07  2.600008e+07
# 50%    2.600002e+07  2.600003e+07  2.600004e+07  2.600006e+07  2.700000e+07
# 75%    2.600003e+07  2.600004e+07  2.600006e+07  2.600007e+07  2.800000e+07
# max    2.600005e+07  2.600006e+07  2.600008e+07  2.800001e+07  2.800001e+07
#
#            p2_unit7      p2_unit8
# count  2.900000e+01  2.900000e+01
# mean   2.789656e+07  2.800001e+07
# std    4.092431e+05  3.892015e+00
# min    2.600006e+07  2.800000e+07
# 25%    2.800000e+07  2.800001e+07
# 50%    2.800000e+07  2.800001e+07
# 75%    2.800001e+07  2.800002e+07
# max    2.800001e+07  2.800002e+07
#
# [8 rows x 21 columns]
# gs://tom-duong-project-bucket/landing Columns with null values
# []
# gs://tom-duong-project-bucket/landing Number of Rows with null values: 0
# gs://tom-duong-project-bucket/landing Integer data type columns: Index(['match_ID', 'p1_trophies', 'p1_crowns_obtained', 'p1_unit1', 'p1_unit2',
#        'p1_unit3', 'p1_unit4', 'p1_unit5', 'p1_unit6', 'p1_unit7', 'p1_unit8',
#        'p2_trophies', 'p2_crowns_obtained', 'p2_unit1', 'p2_unit2', 'p2_unit3',
#        'p2_unit4', 'p2_unit5', 'p2_unit6', 'p2_unit7', 'p2_unit8'],
#       dtype='object')
# gs://tom-duong-project-bucket/landing Float data type columns: Index([], dtype='object')
# gs://tom-duong-project-bucket/landing Unique items in p1_unit1 to p1_unit8:
# p1_unit1    11
# p1_unit2    14
# p1_unit3    15
# p1_unit4    16
# p1_unit5    16
# p1_unit6    15
# p1_unit7     9
# p1_unit8     9
# dtype: int64
# gs://tom-duong-project-bucket/landing Unique items in p2_unit1 to p2_unit8:
# p2_unit1    18
# p2_unit2    19
# p2_unit3    18
# p2_unit4    19
# p2_unit5    20
# p2_unit6    17
# p2_unit7    15
# p2_unit8    10
# dtype: int64
# gs://tom-duong-project-bucket/landing Unique items in p1_crowns_obtained: 4
# gs://tom-duong-project-bucket/landing Unique items in p2_crowns_obtained: 4
# Working on file 20220907.csv
# gs://tom-duong-project-bucket/landing Number of records:
# date                  85
# match_ID              85
# p1_tag                85
# p1_trophies           85
# p1_crowns_obtained    85
# p1_unit1              85
# p1_unit2              85
# p1_unit3              85
# p1_unit4              85
# p1_unit5              85
# p1_unit6              85
# p1_unit7              85
# p1_unit8              85
# p2_tag                85
# p2_trophies           85
# p2_crowns_obtained    85
# p2_unit1              85
# p2_unit2              85
# p2_unit3              85
# p2_unit4              85
# p2_unit5              85
# p2_unit6              85
# p2_unit7              85
# p2_unit8              85
# dtype: int64
# gs://tom-duong-project-bucket/landing Number of variables:
# 24
# gs://tom-duong-project-bucket/landing Number of duplicate records: 0
# gs://tom-duong-project-bucket/landing Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                85 non-null     object
#  1   match_ID            85 non-null     int64
#  2   p1_tag              85 non-null     object
#  3   p1_trophies         85 non-null     int64
#  4   p1_crowns_obtained  85 non-null     int64
#  5   p1_unit1            85 non-null     int64
#  6   p1_unit2            85 non-null     int64
#  7   p1_unit3            85 non-null     int64
#  8   p1_unit4            85 non-null     int64
#  9   p1_unit5            85 non-null     int64
#  10  p1_unit6            85 non-null     int64
#  11  p1_unit7            85 non-null     int64
#  12  p1_unit8            85 non-null     int64
#  13  p2_tag              85 non-null     object
#  14  p2_trophies         85 non-null     int64
#  15  p2_crowns_obtained  85 non-null     int64
#  16  p2_unit1            85 non-null     int64
#  17  p2_unit2            85 non-null     int64
#  18  p2_unit3            85 non-null     int64
#  19  p2_unit4            85 non-null     int64
#  20  p2_unit5            85 non-null     int64
#  21  p2_unit6            85 non-null     int64
#  22  p2_unit7            85 non-null     int64
#  23  p2_unit8            85 non-null     int64
# dtypes: int64(21), object(3)
# memory usage: 16.1+ KB
# None
# gs://tom-duong-project-bucket/landing Describe
#            match_ID  p1_trophies  p1_crowns_obtained      p1_unit1  \
# count  8.500000e+01    85.000000           85.000000  8.500000e+01
# mean   7.200013e+07  6157.388235            1.235294  2.600001e+07
# std    1.390923e+02   613.515749            1.181676  1.087872e+01
# min    7.200001e+07  5030.000000            0.000000  2.600000e+07
# 25%    7.200001e+07  5675.000000            0.000000  2.600001e+07
# 50%    7.200001e+07  6570.000000            1.000000  2.600001e+07
# 75%    7.200029e+07  6630.000000            2.000000  2.600002e+07
# max    7.200029e+07  6763.000000            3.000000  2.600005e+07
#
#            p1_unit2      p1_unit3      p1_unit4      p1_unit5      p1_unit6  \
# count  8.500000e+01  8.500000e+01  8.500000e+01  8.500000e+01  8.500000e+01
# mean   2.600002e+07  2.600004e+07  2.602358e+07  2.625886e+07  2.689415e+07
# std    1.371529e+01  1.530130e+01  1.524709e+05  4.405662e+05  8.731672e+05
# min    2.600000e+07  2.600001e+07  2.600002e+07  2.600002e+07  2.600003e+07
# 25%    2.600001e+07  2.600002e+07  2.600004e+07  2.600004e+07  2.600006e+07
# 50%    2.600002e+07  2.600003e+07  2.600005e+07  2.600006e+07  2.700000e+07
# 75%    2.600003e+07  2.600005e+07  2.600006e+07  2.700000e+07  2.800000e+07
# max    2.600006e+07  2.600007e+07  2.700001e+07  2.700001e+07  2.800001e+07
#
#            p1_unit7  ...  p2_trophies  p2_crowns_obtained      p2_unit1  \
# count  8.500000e+01  ...    85.000000           85.000000  8.500000e+01
# mean   2.784707e+07  ...  6025.705882            0.917647  2.600001e+07
# std    5.001284e+05  ...   621.405240            0.966237  1.380765e+01
# min    2.600004e+07  ...  5005.000000            0.000000  2.600000e+07
# 25%    2.800000e+07  ...  5331.000000            0.000000  2.600001e+07
# 50%    2.800000e+07  ...  6226.000000            1.000000  2.600001e+07
# 75%    2.800000e+07  ...  6620.000000            1.000000  2.600002e+07
# max    2.800001e+07  ...  6736.000000            3.000000  2.600005e+07
#
#            p2_unit2      p2_unit3      p2_unit4      p2_unit5      p2_unit6  \
# count  8.500000e+01  8.500000e+01  8.500000e+01  8.500000e+01  8.500000e+01
# mean   2.600002e+07  2.600003e+07  2.604710e+07  2.630592e+07  2.692944e+07
# std    1.413469e+01  1.551436e+01  2.130131e+05  5.122935e+05  8.835314e+05
# min    2.600000e+07  2.600001e+07  2.600002e+07  2.600002e+07  2.600003e+07
# 25%    2.600001e+07  2.600002e+07  2.600004e+07  2.600004e+07  2.600006e+07
# 50%    2.600002e+07  2.600003e+07  2.600005e+07  2.600006e+07  2.700001e+07
# 75%    2.600003e+07  2.600004e+07  2.600006e+07  2.700000e+07  2.800000e+07
# max    2.600005e+07  2.600006e+07  2.700001e+07  2.800001e+07  2.800001e+07
#
#            p2_unit7      p2_unit8
# count  8.500000e+01  8.500000e+01
# mean   2.787060e+07  2.797648e+07
# std    4.827451e+05  2.169247e+05
# min    2.600003e+07  2.600006e+07
# 25%    2.800000e+07  2.800001e+07
# 50%    2.800000e+07  2.800001e+07
# 75%    2.800001e+07  2.800001e+07
# max    2.800002e+07  2.800002e+07
#
# [8 rows x 21 columns]
# gs://tom-duong-project-bucket/landing Columns with null values
# []
# gs://tom-duong-project-bucket/landing Number of Rows with null values: 0
# gs://tom-duong-project-bucket/landing Integer data type columns: Index(['match_ID', 'p1_trophies', 'p1_crowns_obtained', 'p1_unit1', 'p1_unit2',
#        'p1_unit3', 'p1_unit4', 'p1_unit5', 'p1_unit6', 'p1_unit7', 'p1_unit8',
#        'p2_trophies', 'p2_crowns_obtained', 'p2_unit1', 'p2_unit2', 'p2_unit3',
#        'p2_unit4', 'p2_unit5', 'p2_unit6', 'p2_unit7', 'p2_unit8'],
#       dtype='object')
# gs://tom-duong-project-bucket/landing Float data type columns: Index([], dtype='object')
# gs://tom-duong-project-bucket/landing Unique items in p1_unit1 to p1_unit8:
# p1_unit1    21
# p1_unit2    28
# p1_unit3    34
# p1_unit4    29
# p1_unit5    29
# p1_unit6    33
# p1_unit7    18
# p1_unit8    15
# dtype: int64
# gs://tom-duong-project-bucket/landing Unique items in p2_unit1 to p2_unit8:
# p2_unit1    20
# p2_unit2    24
# p2_unit3    30
# p2_unit4    32
# p2_unit5    31
# p2_unit6    32
# p2_unit7    18
# p2_unit8    15
# dtype: int64
# gs://tom-duong-project-bucket/landing Unique items in p1_crowns_obtained: 4
# gs://tom-duong-project-bucket/landing Unique items in p2_crowns_obtained: 4
# Working on file 20220908.csv
# gs://tom-duong-project-bucket/landing Number of records:
# date                  23
# match_ID              23
# p1_tag                23
# p1_trophies           23
# p1_crowns_obtained    23
# p1_unit1              23
# p1_unit2              23
# p1_unit3              23
# p1_unit4              23
# p1_unit5              23
# p1_unit6              23
# p1_unit7              23
# p1_unit8              23
# p2_tag                23
# p2_trophies           23
# p2_crowns_obtained    23
# p2_unit1              23
# p2_unit2              23
# p2_unit3              23
# p2_unit4              23
# p2_unit5              23
# p2_unit6              23
# p2_unit7              23
# p2_unit8              23
# dtype: int64
# gs://tom-duong-project-bucket/landing Number of variables:
# 24
# gs://tom-duong-project-bucket/landing Number of duplicate records: 0
# gs://tom-duong-project-bucket/landing Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                23 non-null     object
#  1   match_ID            23 non-null     int64
#  2   p1_tag              23 non-null     object
#  3   p1_trophies         23 non-null     int64
#  4   p1_crowns_obtained  23 non-null     int64
#  5   p1_unit1            23 non-null     int64
#  6   p1_unit2            23 non-null     int64
#  7   p1_unit3            23 non-null     int64
#  8   p1_unit4            23 non-null     int64
#  9   p1_unit5            23 non-null     int64
#  10  p1_unit6            23 non-null     int64
#  11  p1_unit7            23 non-null     int64
#  12  p1_unit8            23 non-null     int64
#  13  p2_tag              23 non-null     object
#  14  p2_trophies         23 non-null     int64
#  15  p2_crowns_obtained  23 non-null     int64
#  16  p2_unit1            23 non-null     int64
#  17  p2_unit2            23 non-null     int64
#  18  p2_unit3            23 non-null     int64
#  19  p2_unit4            23 non-null     int64
#  20  p2_unit5            23 non-null     int64
#  21  p2_unit6            23 non-null     int64
#  22  p2_unit7            23 non-null     int64
#  23  p2_unit8            23 non-null     int64
# dtypes: int64(21), object(3)
# memory usage: 4.4+ KB
# None
# gs://tom-duong-project-bucket/landing Describe
#            match_ID  p1_trophies  p1_crowns_obtained      p1_unit1  \
# count  2.300000e+01    23.000000           23.000000  2.300000e+01
# mean   7.200009e+07  5959.956522            1.260870  2.600001e+07
# std    1.340845e+02   474.323104            1.214211  5.961669e+00
# min    7.200001e+07  5008.000000            0.000000  2.600000e+07
# 25%    7.200001e+07  5610.500000            0.000000  2.600001e+07
# 50%    7.200001e+07  6053.000000            1.000000  2.600001e+07
# 75%    7.200029e+07  6341.500000            2.500000  2.600001e+07
# max    7.200029e+07  6479.000000            3.000000  2.600002e+07
#
#            p1_unit2      p1_unit3      p1_unit4      p1_unit5      p1_unit6  \
# count  2.300000e+01  2.300000e+01  2.300000e+01  2.300000e+01  2.300000e+01
# mean   2.600002e+07  2.600003e+07  2.600004e+07  2.634786e+07  2.691307e+07
# std    1.076537e+01  9.889708e+00  1.300851e+01  4.869602e+05  9.001282e+05
# min    2.600001e+07  2.600002e+07  2.600003e+07  2.600004e+07  2.600005e+07
# 25%    2.600001e+07  2.600003e+07  2.600004e+07  2.600005e+07  2.600006e+07
# 50%    2.600002e+07  2.600003e+07  2.600004e+07  2.600006e+07  2.700000e+07
# 75%    2.600003e+07  2.600004e+07  2.600005e+07  2.700000e+07  2.800000e+07
# max    2.600005e+07  2.600006e+07  2.600007e+07  2.700001e+07  2.800001e+07
#
#            p1_unit7  ...  p2_trophies  p2_crowns_obtained      p2_unit1  \
# count  2.300000e+01  ...    23.000000           23.000000  2.300000e+01
# mean   2.782610e+07  ...  5934.695652            1.173913  2.600001e+07
# std    5.761922e+05  ...   409.560789            1.266785  1.216894e+01
# min    2.600006e+07  ...  5110.000000            0.000000  2.600000e+07
# 25%    2.800000e+07  ...  5632.500000            0.000000  2.600001e+07
# 50%    2.800000e+07  ...  5886.000000            1.000000  2.600001e+07
# 75%    2.800001e+07  ...  6345.000000            2.500000  2.600002e+07
# max    2.800001e+07  ...  6419.000000            3.000000  2.600005e+07
#
#            p2_unit2      p2_unit3      p2_unit4      p2_unit5      p2_unit6  \
# count  2.300000e+01  2.300000e+01  2.300000e+01  2.300000e+01  2.300000e+01
# mean   2.600002e+07  2.600003e+07  2.600005e+07  2.621744e+07  2.686959e+07
# std    1.160670e+01  1.274173e+01  1.641760e+01  4.217187e+05  8.148578e+05
# min    2.600001e+07  2.600002e+07  2.600002e+07  2.600003e+07  2.600003e+07
# 25%    2.600002e+07  2.600003e+07  2.600004e+07  2.600005e+07  2.600006e+07
# 50%    2.600002e+07  2.600003e+07  2.600004e+07  2.600006e+07  2.700001e+07
# 75%    2.600003e+07  2.600004e+07  2.600006e+07  2.600008e+07  2.750000e+07
# max    2.600006e+07  2.600006e+07  2.600008e+07  2.700001e+07  2.800001e+07
#
#            p2_unit7      p2_unit8
# count  2.300000e+01  2.300000e+01
# mean   2.778262e+07  2.800001e+07
# std    5.997209e+05  4.175025e+00
# min    2.600006e+07  2.800000e+07
# 25%    2.800000e+07  2.800001e+07
# 50%    2.800000e+07  2.800001e+07
# 75%    2.800000e+07  2.800001e+07
# max    2.800001e+07  2.800002e+07
#
# [8 rows x 21 columns]
# gs://tom-duong-project-bucket/landing Columns with null values
# []
# gs://tom-duong-project-bucket/landing Number of Rows with null values: 0
# gs://tom-duong-project-bucket/landing Integer data type columns: Index(['match_ID', 'p1_trophies', 'p1_crowns_obtained', 'p1_unit1', 'p1_unit2',
#        'p1_unit3', 'p1_unit4', 'p1_unit5', 'p1_unit6', 'p1_unit7', 'p1_unit8',
#        'p2_trophies', 'p2_crowns_obtained', 'p2_unit1', 'p2_unit2', 'p2_unit3',
#        'p2_unit4', 'p2_unit5', 'p2_unit6', 'p2_unit7', 'p2_unit8'],
#       dtype='object')
# gs://tom-duong-project-bucket/landing Float data type columns: Index([], dtype='object')
# gs://tom-duong-project-bucket/landing Unique items in p1_unit1 to p1_unit8:
# p1_unit1    11
# p1_unit2    11
# p1_unit3    14
# p1_unit4    15
# p1_unit5    12
# p1_unit6    15
# p1_unit7    11
# p1_unit8     9
# dtype: int64
# gs://tom-duong-project-bucket/landing Unique items in p2_unit1 to p2_unit8:
# p2_unit1    15
# p2_unit2    17
# p2_unit3    17
# p2_unit4    15
# p2_unit5    16
# p2_unit6    17
# p2_unit7    11
# p2_unit8    10
# dtype: int64
# gs://tom-duong-project-bucket/landing Unique items in p1_crowns_obtained: 4
# gs://tom-duong-project-bucket/landing Unique items in p2_crowns_obtained: 4
# Working on file 20220909.csv
# gs://tom-duong-project-bucket/landing Number of records:
# date                  26
# match_ID              26
# p1_tag                26
# p1_trophies           26
# p1_crowns_obtained    26
# p1_unit1              26
# p1_unit2              26
# p1_unit3              26
# p1_unit4              26
# p1_unit5              26
# p1_unit6              26
# p1_unit7              26
# p1_unit8              26
# p2_tag                26
# p2_trophies           26
# p2_crowns_obtained    26
# p2_unit1              26
# p2_unit2              26
# p2_unit3              26
# p2_unit4              26
# p2_unit5              26
# p2_unit6              26
# p2_unit7              26
# p2_unit8              26
# dtype: int64
# gs://tom-duong-project-bucket/landing Number of variables:
# 24
# gs://tom-duong-project-bucket/landing Number of duplicate records: 0
# gs://tom-duong-project-bucket/landing Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                26 non-null     object
#  1   match_ID            26 non-null     int64
#  2   p1_tag              26 non-null     object
#  3   p1_trophies         26 non-null     int64
#  4   p1_crowns_obtained  26 non-null     int64
#  5   p1_unit1            26 non-null     int64
#  6   p1_unit2            26 non-null     int64
#  7   p1_unit3            26 non-null     int64
#  8   p1_unit4            26 non-null     int64
#  9   p1_unit5            26 non-null     int64
#  10  p1_unit6            26 non-null     int64
#  11  p1_unit7            26 non-null     int64
#  12  p1_unit8            26 non-null     int64
#  13  p2_tag              26 non-null     object
#  14  p2_trophies         26 non-null     int64
#  15  p2_crowns_obtained  26 non-null     int64
#  16  p2_unit1            26 non-null     int64
#  17  p2_unit2            26 non-null     int64
#  18  p2_unit3            26 non-null     int64
#  19  p2_unit4            26 non-null     int64
#  20  p2_unit5            26 non-null     int64
#  21  p2_unit6            26 non-null     int64
#  22  p2_unit7            26 non-null     int64
#  23  p2_unit8            26 non-null     int64
# dtypes: int64(21), object(3)
# memory usage: 5.0+ KB
# None
# gs://tom-duong-project-bucket/landing Describe
#            match_ID  p1_trophies  p1_crowns_obtained      p1_unit1  \
# count  2.600000e+01    26.000000           26.000000  2.600000e+01
# mean   7.200013e+07  5523.307692            1.230769  2.600001e+07
# std    1.183836e+02   456.868363            1.142198  1.021372e+01
# min    7.200001e+07  5058.000000            0.000000  2.600000e+07
# 25%    7.200004e+07  5142.750000            0.000000  2.600001e+07
# 50%    7.200007e+07  5346.000000            1.000000  2.600001e+07
# 75%    7.200029e+07  5886.000000            2.000000  2.600002e+07
# max    7.200029e+07  6943.000000            3.000000  2.600005e+07
#
#            p1_unit2      p1_unit3      p1_unit4      p1_unit5      p1_unit6  \
# count  2.600000e+01  2.600000e+01  2.600000e+01  2.600000e+01  2.600000e+01
# mean   2.600002e+07  2.600003e+07  2.600004e+07  2.623081e+07  2.688464e+07
# std    1.306622e+01  1.306086e+01  1.585807e+01  5.143900e+05  8.161554e+05
# min    2.600001e+07  2.600001e+07  2.600001e+07  2.600003e+07  2.600004e+07
# 25%    2.600001e+07  2.600002e+07  2.600003e+07  2.600004e+07  2.600008e+07
# 50%    2.600002e+07  2.600003e+07  2.600004e+07  2.600005e+07  2.700000e+07
# 75%    2.600003e+07  2.600004e+07  2.600006e+07  2.600008e+07  2.775000e+07
# max    2.600005e+07  2.600006e+07  2.600008e+07  2.800000e+07  2.800001e+07
#
#            p1_unit7  ...  p2_trophies  p2_crowns_obtained      p2_unit1  \
# count  2.600000e+01  ...    26.000000           26.000000  2.600000e+01
# mean   2.780770e+07  ...  5614.653846            0.961538  2.600001e+07
# std    5.670298e+05  ...   513.814826            0.773603  1.033322e+01
# min    2.600006e+07  ...  5064.000000            0.000000  2.600000e+07
# 25%    2.800000e+07  ...  5196.250000            0.250000  2.600001e+07
# 50%    2.800000e+07  ...  5594.000000            1.000000  2.600001e+07
# 75%    2.800000e+07  ...  5886.000000            1.000000  2.600001e+07
# max    2.800001e+07  ...  7016.000000            3.000000  2.600005e+07
#
#            p2_unit2      p2_unit3      p2_unit4      p2_unit5      p2_unit6  \
# count  2.600000e+01  2.600000e+01  2.600000e+01  2.600000e+01  2.600000e+01
# mean   2.600002e+07  2.600003e+07  2.603850e+07  2.623081e+07  2.692311e+07
# std    1.199519e+01  1.052236e+01  1.961089e+05  5.143916e+05  9.347699e+05
# min    2.600001e+07  2.600001e+07  2.600002e+07  2.600002e+07  2.600004e+07
# 25%    2.600001e+07  2.600003e+07  2.600003e+07  2.600004e+07  2.600006e+07
# 50%    2.600002e+07  2.600003e+07  2.600004e+07  2.600005e+07  2.700000e+07
# 75%    2.600003e+07  2.600004e+07  2.600006e+07  2.600007e+07  2.800000e+07
# max    2.600006e+07  2.600006e+07  2.700001e+07  2.800000e+07  2.800001e+07
#
#            p2_unit7      p2_unit8
# count  2.600000e+01  2.600000e+01
# mean   2.773078e+07  2.800001e+07
# std    6.667779e+05  4.417622e+00
# min    2.600006e+07  2.800000e+07
# 25%    2.800000e+07  2.800001e+07
# 50%    2.800001e+07  2.800001e+07
# 75%    2.800001e+07  2.800002e+07
# max    2.800002e+07  2.800002e+07
#
# [8 rows x 21 columns]
# gs://tom-duong-project-bucket/landing Columns with null values
# []
# gs://tom-duong-project-bucket/landing Number of Rows with null values: 0
# gs://tom-duong-project-bucket/landing Integer data type columns: Index(['match_ID', 'p1_trophies', 'p1_crowns_obtained', 'p1_unit1', 'p1_unit2',
#        'p1_unit3', 'p1_unit4', 'p1_unit5', 'p1_unit6', 'p1_unit7', 'p1_unit8',
#        'p2_trophies', 'p2_crowns_obtained', 'p2_unit1', 'p2_unit2', 'p2_unit3',
#        'p2_unit4', 'p2_unit5', 'p2_unit6', 'p2_unit7', 'p2_unit8'],
#       dtype='object')
# gs://tom-duong-project-bucket/landing Float data type columns: Index([], dtype='object')
# gs://tom-duong-project-bucket/landing Unique items in p1_unit1 to p1_unit8:
# p1_unit1    16
# p1_unit2    18
# p1_unit3    18
# p1_unit4    17
# p1_unit5    19
# p1_unit6    18
# p1_unit7    10
# p1_unit8     9
# dtype: int64
# gs://tom-duong-project-bucket/landing Unique items in p2_unit1 to p2_unit8:
# p2_unit1    11
# p2_unit2    17
# p2_unit3    16
# p2_unit4    17
# p2_unit5    16
# p2_unit6    19
# p2_unit7    13
# p2_unit8    11
# dtype: int64
# gs://tom-duong-project-bucket/landing Unique items in p1_crowns_obtained: 4
# gs://tom-duong-project-bucket/landing Unique items in p2_crowns_obtained: 4
# Working on file 20220910.csv
# gs://tom-duong-project-bucket/landing Number of records:
# date                  53
# match_ID              53
# p1_tag                53
# p1_trophies           53
# p1_crowns_obtained    53
# p1_unit1              53
# p1_unit2              53
# p1_unit3              53
# p1_unit4              53
# p1_unit5              53
# p1_unit6              53
# p1_unit7              53
# p1_unit8              53
# p2_tag                53
# p2_trophies           53
# p2_crowns_obtained    53
# p2_unit1              53
# p2_unit2              53
# p2_unit3              53
# p2_unit4              53
# p2_unit5              53
# p2_unit6              53
# p2_unit7              53
# p2_unit8              53
# dtype: int64
# gs://tom-duong-project-bucket/landing Number of variables:
# 24
# gs://tom-duong-project-bucket/landing Number of duplicate records: 0
# gs://tom-duong-project-bucket/landing Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                53 non-null     object
#  1   match_ID            53 non-null     int64
#  2   p1_tag              53 non-null     object
#  3   p1_trophies         53 non-null     int64
#  4   p1_crowns_obtained  53 non-null     int64
#  5   p1_unit1            53 non-null     int64
#  6   p1_unit2            53 non-null     int64
#  7   p1_unit3            53 non-null     int64
#  8   p1_unit4            53 non-null     int64
#  9   p1_unit5            53 non-null     int64
#  10  p1_unit6            53 non-null     int64
#  11  p1_unit7            53 non-null     int64
#  12  p1_unit8            53 non-null     int64
#  13  p2_tag              53 non-null     object
#  14  p2_trophies         53 non-null     int64
#  15  p2_crowns_obtained  53 non-null     int64
#  16  p2_unit1            53 non-null     int64
#  17  p2_unit2            53 non-null     int64
#  18  p2_unit3            53 non-null     int64
#  19  p2_unit4            53 non-null     int64
#  20  p2_unit5            53 non-null     int64
#  21  p2_unit6            53 non-null     int64
#  22  p2_unit7            53 non-null     int64
#  23  p2_unit8            53 non-null     int64
# dtypes: int64(21), object(3)
# memory usage: 10.1+ KB
# None
# gs://tom-duong-project-bucket/landing Describe
#            match_ID  p1_trophies  p1_crowns_obtained      p1_unit1  \
# count  5.300000e+01    53.000000           53.000000  5.300000e+01
# mean   7.200012e+07  6281.584906            1.094340  2.600001e+07
# std    1.144770e+02   708.251271            1.078891  1.049265e+01
# min    7.200004e+07  5026.000000            0.000000  2.600000e+07
# 25%    7.200004e+07  5709.000000            0.000000  2.600000e+07
# 50%    7.200004e+07  6193.000000            1.000000  2.600001e+07
# 75%    7.200029e+07  7005.000000            2.000000  2.600001e+07
# max    7.200029e+07  7102.000000            3.000000  2.600005e+07
#
#            p1_unit2      p1_unit3      p1_unit4      p1_unit5      p1_unit6  \
# count  5.300000e+01  5.300000e+01  5.300000e+01  5.300000e+01  5.300000e+01
# mean   2.600002e+07  2.600003e+07  2.600004e+07  2.601893e+07  2.664154e+07
# std    1.159353e+01  8.876266e+00  1.091998e+01  1.373534e+05  6.532031e+05
# min    2.600001e+07  2.600001e+07  2.600002e+07  2.600002e+07  2.600004e+07
# 25%    2.600001e+07  2.600003e+07  2.600004e+07  2.600005e+07  2.600006e+07
# 50%    2.600002e+07  2.600003e+07  2.600004e+07  2.600006e+07  2.700000e+07
# 75%    2.600003e+07  2.600004e+07  2.600005e+07  2.600008e+07  2.700001e+07
# max    2.600005e+07  2.600006e+07  2.600008e+07  2.700001e+07  2.800001e+07
#
#            p1_unit7  ...  p2_trophies  p2_crowns_obtained      p2_unit1  \
# count  5.300000e+01  ...    53.000000           53.000000  5.300000e+01
# mean   2.766039e+07  ...  6288.415094            1.056604  2.600001e+07
# std    6.487531e+05  ...   715.590086            1.026853  8.017624e+00
# min    2.600005e+07  ...  4975.000000            0.000000  2.600000e+07
# 25%    2.800000e+07  ...  5680.000000            0.000000  2.600001e+07
# 50%    2.800000e+07  ...  6226.000000            1.000000  2.600001e+07
# 75%    2.800000e+07  ...  6976.000000            1.000000  2.600002e+07
# max    2.800002e+07  ...  7218.000000            3.000000  2.600004e+07
#
#            p2_unit2      p2_unit3      p2_unit4      p2_unit5      p2_unit6  \
# count  5.300000e+01  5.300000e+01  5.300000e+01  5.300000e+01  5.300000e+01
# mean   2.600002e+07  2.600004e+07  2.603778e+07  2.633966e+07  2.698116e+07
# std    1.088054e+01  1.473333e+01  1.923724e+05  5.864732e+05  8.432877e+05
# min    2.600001e+07  2.600001e+07  2.600002e+07  2.600003e+07  2.600004e+07
# 25%    2.600002e+07  2.600002e+07  2.600004e+07  2.600005e+07  2.600006e+07
# 50%    2.600002e+07  2.600004e+07  2.600005e+07  2.600006e+07  2.700000e+07
# 75%    2.600003e+07  2.600005e+07  2.600006e+07  2.700000e+07  2.800000e+07
# max    2.600005e+07  2.600007e+07  2.700001e+07  2.800001e+07  2.800001e+07
#
#            p2_unit7      p2_unit8
# count  5.300000e+01  5.300000e+01
# mean   2.790567e+07  2.800001e+07
# std    4.049659e+05  3.848265e+00
# min    2.600006e+07  2.800000e+07
# 25%    2.800000e+07  2.800001e+07
# 50%    2.800001e+07  2.800001e+07
# 75%    2.800001e+07  2.800002e+07
# max    2.800002e+07  2.800002e+07
#
# [8 rows x 21 columns]
# gs://tom-duong-project-bucket/landing Columns with null values
# []
# gs://tom-duong-project-bucket/landing Number of Rows with null values: 0
# gs://tom-duong-project-bucket/landing Integer data type columns: Index(['match_ID', 'p1_trophies', 'p1_crowns_obtained', 'p1_unit1', 'p1_unit2',
#        'p1_unit3', 'p1_unit4', 'p1_unit5', 'p1_unit6', 'p1_unit7', 'p1_unit8',
#        'p2_trophies', 'p2_crowns_obtained', 'p2_unit1', 'p2_unit2', 'p2_unit3',
#        'p2_unit4', 'p2_unit5', 'p2_unit6', 'p2_unit7', 'p2_unit8'],
#       dtype='object')
# gs://tom-duong-project-bucket/landing Float data type columns: Index([], dtype='object')
# gs://tom-duong-project-bucket/landing Unique items in p1_unit1 to p1_unit8:
# p1_unit1    15
# p1_unit2    18
# p1_unit3    17
# p1_unit4    17
# p1_unit5    16
# p1_unit6    16
# p1_unit7    15
# p1_unit8    12
# dtype: int64
# gs://tom-duong-project-bucket/landing Unique items in p2_unit1 to p2_unit8:
# p2_unit1    20
# p2_unit2    28
# p2_unit3    29
# p2_unit4    32
# p2_unit5    26
# p2_unit6    25
# p2_unit7    16
# p2_unit8    12
# dtype: int64
# gs://tom-duong-project-bucket/landing Unique items in p1_crowns_obtained: 4
# gs://tom-duong-project-bucket/landing Unique items in p2_crowns_obtained: 4
